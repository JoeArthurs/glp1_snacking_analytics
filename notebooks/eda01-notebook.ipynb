# %%
from sqlalchemy import create_engine, text
from sqlalchemy.engine import URL

connection_url = URL.create(
    drivername="postgresql",
    username="glp1_user",
    password="Medull@2026",  # special characters are fine here
    host="localhost",
    database="glp1_analytics"
)

engine = create_engine(connection_url)
with engine.connect() as conn:
    print("Connected:", conn.execute(text("SELECT version()")).scalar())
# Out:
# Connected: PostgreSQL 18.3 on x86_64-windows, compiled by msvc-19.44.35225, 64-bit
